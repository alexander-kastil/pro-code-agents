# %% [markdown]
# This is an intro to jupyter notebook and python. It is a simple example of how to use jupyter notebook and python to solve a simple problem. You can hove the `play button` on the left to run the code. You can also edit the code and run it again.

# %%
# This is a comment in a Jupyter Notebook cell
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Next we will use it to install the required packages in the virtual environment using the requirements.txt file instead of executing the command `pip install requests`. This is useful when you want to share your code with others and they can easily install the required packages using the requirements.txt file, especially when you have many packages to install.
#
# Because `pip install` is a shell command and we are using jupyter notebook, we will use the `%` or `!` to execute the shell command.

# %%
# Install requirements in python
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests

def fetch_and_write(url, filename):
    # Send a HTTP request to the URL
    response = requests.get(url)

    # Check the status of the request
    if response.status_code == 200:
        # Write the content to a file
        with open(filename, 'w') as file:
            file.write(response.text)
            print(f"Content written to {filename}")
    else:
        print(f"Failed to fetch the content from {url}. Status code: {response.status_code}")
        
# Call the say_hello method
fetch_and_write('https://www.integrations.at', 'integration.html')
# Out:
# Content written to integration.html
